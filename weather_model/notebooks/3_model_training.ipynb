# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %store -r X_scaled
X_scaled = X_scaled

# %%
# instantiate the model
kmeans = KMeans(n_clusters=4)  # Taking 4, random guess
# fit the model
kmeans.fit(X_scaled)
# make predictions
y_pred = kmeans.predict(X_scaled)
print(y_pred)

print("\n")
print(kmeans.cluster_centers_) # See the cluster centres
print("\n")
# Out:
# [1 1 1 ... 0 1 1]
#
#
# [[-0.06924368  0.00362437]
#  [ 0.93434411 -0.85769239]
#  [-1.9096483   2.35297018]
#  [-1.28280529  1.07287048]]

# %%
# Data Visualization
# plot the scaled data
plt.scatter(X_scaled[:,0],
            X_scaled[:,1],
            c= y_pred)
# identify the centroids
plt.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            marker="*",
            s = 250,
            c = [0,1,2,3], # 4 k clusters thus 4 arguments
            edgecolors='k')

plt.xlabel('temperature')
plt.ylabel('humidity')
plt.title('k-means (k=4)')
plt.savefig("../output/n_plot_centroid.png")
plt.show()

# %%
# Store the model
# %store kmeans
# Out:
# Stored 'kmeans' (KMeans)
